# %%
import pandas as pd
import seaborn as sns
df= sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# !pip install --upgrade joblib visions
# Out:
# Requirement already satisfied: joblib in c:\users\hp\anaconda\lib\site-packages (1.5.3)
# Requirement already satisfied: visions in c:\users\hp\anaconda\lib\site-packages (0.8.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hp\anaconda\lib\site-packages (from visions) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\hp\anaconda\lib\site-packages (from visions) (2.2.2)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hp\anaconda\lib\site-packages (from visions) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hp\anaconda\lib\site-packages (from visions) (3.3)
# Requirement already satisfied: multimethod>=1.4 in c:\users\hp\anaconda\lib\site-packages (from visions) (1.12)
# Requirement already satisfied: puremagic in c:\users\hp\anaconda\lib\site-packages (from visions) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda\lib\site-packages (from pandas>=2.0.0->visions) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda\lib\site-packages (from pandas>=2.0.0->visions) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda\lib\site-packages (from pandas>=2.0.0->visions) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->visions) (1.16.0)

# %%
# !pip list | findstr profiling
# Out:
# ydata-profiling                   4.18.1

# %%
# !pip show joblib visions scikit-learn ydata-profiling
# Out:
# Name: joblib
# Version: 1.5.3
# Summary: Lightweight pipelining with Python functions
# Home-page: https://joblib.readthedocs.io
# Author:
# Author-email: Gael Varoquaux <gael.varoquaux@normalesup.org>
# License:
# Location: C:\Users\hp\anaconda\Lib\site-packages
# Requires:
# Required-by: imbalanced-learn, nltk, phik, scikit-learn
# ---
# Name: visions
# Version: 0.8.1
# Summary: Visions
# Home-page:
# Author:
# Author-email: Dylan Profiler <visions@ictopzee.nl>
# License: BSD License
# Location: C:\Users\hp\anaconda\Lib\site-packages
# Requires: attrs, multimethod, networkx, numpy, pandas, puremagic
# Required-by: ydata-profiling
# ---
# Name: scikit-learn
# Version: 1.5.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: C:\Users\hp\anaconda\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: imbalanced-learn
# ---
# Name: ydata-profiling
# Version: 4.18.1
# Summary: Generate profile report for pandas DataFrame
# Home-page: https://ydata.ai
# Author:
# Author-email: YData Labs Inc <opensource@ydata.ai>
# License:
# Location: C:\Users\hp\anaconda\Lib\site-packages
# Requires: dacite, filetype, imagehash, jinja2, matplotlib, minify-html, multimethod, numba, numpy, pandas, phik, pydantic, PyYAML, requests, scipy, seaborn, statsmodels, tqdm, typeguard, visions, wordcloud
# Required-by:

# %%
import ydata_profiling
dir(ydata_profiling)
# Out:
# ['NumbaDeprecationWarning',
#  'ProfileReport',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compare',
#  'compare_reports',
#  'config',
#  'controller',
#  'expectations_report',
#  'importlib',
#  'model',
#  'pandas_decorator',
#  'profile_report',
#  'report',
#  'serialize_report',
#  'spec',
#  'spec_numba',
#  'utils',
#  'version',
#  'visualisation',
#  'warnings',
#  'ydata_profiling']

# %%
# !pip install --upgrade ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\hp\anaconda\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\hp\anaconda\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\hp\anaconda\lib\site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\hp\anaconda\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\hp\anaconda\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\hp\anaconda\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator in c:\users\hp\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\hp\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\hp\anaconda\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\hp\anaconda\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\hp\anaconda\lib\site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.27.0
# ipykernel        : 6.28.0
# ipywidgets       : 8.1.8
# jupyter_client   : 8.6.0
# jupyter_core     : 5.7.2
# jupyter_server   : 2.14.1
# jupyterlab       : 4.2.5
# nbclient         : 0.8.0
# nbconvert        : 7.16.4
# nbformat         : 5.10.4
# notebook         : 7.2.2
# qtconsole        : 5.5.1
# traitlets        : 5.14.3

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, progress_bar=False)
profile.to_file("output.html")
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 62.12it/s]

# %%
profile.to_file("output.html")
